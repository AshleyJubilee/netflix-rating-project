# %%
import pandas as pd
from ast import literal_eval
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

import matplotlib.pyplot as plt

# %%
movieData = pd.read_csv("../resources/movieData.csv", converters={'genres': literal_eval, 'production_countries': literal_eval, 'directors': literal_eval, 'actors': literal_eval})
showData = pd.read_csv("../resources/showData.csv", converters={'genres': literal_eval, 'production_countries': literal_eval, 'directors': literal_eval, 'actors': literal_eval})
movieData.drop(columns=['Unnamed: 0', 'id', 'title', 'directors', 'actors', 'release_year'], inplace=True)
showData.drop(columns=['Unnamed: 0', 'id', 'title', 'directors', 'actors', 'release_year'], inplace=True)

# %%
movieEx = movieData.explode(column='genres').explode(column='production_countries').fillna(0)
showEx = showData.explode(column='genres').explode(column='production_countries').fillna(0)
movieEx
# Out:
#      release_decade age_certification  runtime    genres production_countries  \
# 0               70s                 R      114     drama                   US
# 0               70s                 R      114     crime                   US
# 1               70s                 R      109     drama                   US
# 1               70s                 R      109    action                   US
# 1               70s                 R      109  thriller                   US
# ...             ...               ...      ...       ...                  ...
# 3425            20s                 0       93     drama                   EG
# 3426            20s                 0      100   romance                   NG
# 3426            20s                 0      100     drama                   NG
# 3427            20s                 0      134     drama                    0
# 3428            20s                 0       90    comedy                   CO
#
#       imdb_score  imdb_votes
# 0            8.2    808582.0
# 0            8.2    808582.0
# 1            7.7    107673.0
# 1            7.7    107673.0
# 1            7.7    107673.0
# ...          ...         ...
# 3425         5.0       327.0
# 3426         6.8        45.0
# 3426         6.8        45.0
# 3427         7.7       348.0
# 3428         3.8        68.0
#
# [11018 rows x 7 columns]

# %%
replaceProductionMovie = [country for country in movieEx["production_countries"].value_counts().index if movieEx["production_countries"].value_counts()[country] < 135]
for country in replaceProductionMovie:
    movieEx['production_countries'] = movieEx['production_countries'].replace(country, "other")
    showEx['production_countries'] = showEx['production_countries'].replace(country, "other")

# %%
movieDummies = pd.get_dummies(movieEx, columns=['release_decade', 'age_certification', 'genres', 'production_countries'])
movieDummies
# Out:
#       runtime  imdb_score  imdb_votes  release_decade_00s  release_decade_10s  \
# 0         114         8.2    808582.0               False               False
# 0         114         8.2    808582.0               False               False
# 1         109         7.7    107673.0               False               False
# 1         109         7.7    107673.0               False               False
# 1         109         7.7    107673.0               False               False
# ...       ...         ...         ...                 ...                 ...
# 3425       93         5.0       327.0               False               False
# 3426      100         6.8        45.0               False               False
# 3426      100         6.8        45.0               False               False
# 3427      134         7.7       348.0               False               False
# 3428       90         3.8        68.0               False               False
#
#       release_decade_20s  release_decade_50s  release_decade_60s  \
# 0                  False               False               False
# 0                  False               False               False
# 1                  False               False               False
# 1                  False               False               False
# 1                  False               False               False
# ...                  ...                 ...                 ...
# 3425                True               False               False
# 3426                True               False               False
# 3426                True               False               False
# 3427                True               False               False
# 3428                True               False               False
#
#       release_decade_70s  release_decade_80s  ...  production_countries_GB  \
# 0                   True               False  ...                    False
# 0                   True               False  ...                    False
# 1                   True               False  ...                    False
# 1                   True               False  ...                    False
# 1                   True               False  ...                    False
# ...                  ...                 ...  ...                      ...
# 3425               False               False  ...                    False
# 3426               False               False  ...                    False
# 3426               False               False  ...                    False
# 3427               False               False  ...                    False
# 3428               False               False  ...                    False
#
#       production_countries_ID  production_countries_IN  \
# 0                       False                    False
# 0                       False                    False
# 1                       False                    False
# 1                       False                    False
# 1                       False                    False
# ...                       ...                      ...
# 3425                    False                    False
# 3426                    False                    False
# 3426                    False                    False
# 3427                    False                    False
# 3428                    False                    False
#
#       production_countries_IT  production_countries_JP  \
# 0                       False                    False
# 0                       False                    False
# 1                       False                    False
# 1                       False                    False
# 1                       False                    False
# ...                       ...                      ...
# 3425                    False                    False
# 3426                    False                    False
# 3426                    False                    False
# 3427                    False                    False
# 3428                    False                    False
#
#       production_countries_KR  production_countries_MX  \
# 0                       False                    False
# 0                       False                    False
# 1                       False                    False
# 1                       False                    False
# 1                       False                    False
# ...                       ...                      ...
# 3425                    False                    False
# 3426                    False                    False
# 3426                    False                    False
# 3427                    False                    False
# 3428                    False                    False
#
#       production_countries_PH  production_countries_US  \
# 0                       False                     True
# 0                       False                     True
# 1                       False                     True
# 1                       False                     True
# 1                       False                     True
# ...                       ...                      ...
# 3425                    False                    False
# 3426                    False                    False
# 3426                    False                    False
# 3427                    False                    False
# 3428                    False                    False
#
#       production_countries_other
# 0                          False
# 0                          False
# 1                          False
# 1                          False
# 1                          False
# ...                          ...
# 3425                        True
# 3426                        True
# 3426                        True
# 3427                       False
# 3428                        True
#
# [11018 rows x 54 columns]

# %%
showDummies = pd.get_dummies(showEx, columns=['release_decade', 'age_certification', 'genres', 'production_countries', 'seasons'])
showDummies
# Out:
#       runtime  imdb_score  imdb_votes  release_decade_00s  release_decade_10s  \
# 0          30         8.8     73424.0               False               False
# 0          30         8.8     73424.0               False               False
# 1          43         8.1      2151.0               False               False
# 2          24         8.9    308824.0               False               False
# 3          51         6.9     34115.0               False               False
# ...       ...         ...         ...                 ...                 ...
# 1937       37         5.1       738.0               False               False
# 1937       37         5.1       738.0               False               False
# 1938        7         7.8        18.0               False               False
# 1938        7         7.8        18.0               False               False
# 1938        7         7.8        18.0               False               False
#
#       release_decade_20s  release_decade_60s  release_decade_70s  \
# 0                  False                True               False
# 0                  False                True               False
# 1                  False               False                True
# 2                  False               False               False
# 3                  False               False               False
# ...                  ...                 ...                 ...
# 1937                True               False               False
# 1937                True               False               False
# 1938                True               False               False
# 1938                True               False               False
# 1938                True               False               False
#
#       release_decade_80s  release_decade_90s  ...  seasons_19.0  seasons_20.0  \
# 0                  False               False  ...         False         False
# 0                  False               False  ...         False         False
# 1                  False               False  ...         False         False
# 2                   True               False  ...         False         False
# 3                   True               False  ...         False         False
# ...                  ...                 ...  ...           ...           ...
# 1937               False               False  ...         False         False
# 1937               False               False  ...         False         False
# 1938               False               False  ...         False         False
# 1938               False               False  ...         False         False
# 1938               False               False  ...         False         False
#
#       seasons_21.0  seasons_24.0  seasons_25.0  seasons_29.0  seasons_32.0  \
# 0            False         False         False         False         False
# 0            False         False         False         False         False
# 1            False         False         False         False         False
# 2            False         False         False         False         False
# 3            False         False         False         False         False
# ...            ...           ...           ...           ...           ...
# 1937         False         False         False         False         False
# 1937         False         False         False         False         False
# 1938         False         False         False         False         False
# 1938         False         False         False         False         False
# 1938         False         False         False         False         False
#
#       seasons_37.0  seasons_39.0  seasons_42.0
# 0            False         False         False
# 0            False         False         False
# 1            False         False         False
# 2            False         False         False
# 3            False         False         False
# ...            ...           ...           ...
# 1937         False         False         False
# 1937         False         False         False
# 1938         False         False         False
# 1938         False         False         False
# 1938         False         False         False
#
# [5958 rows x 84 columns]

# %%
yShowScore = showDummies['imdb_score']
yMovieScore = movieDummies['imdb_score']
yShowVotes = showDummies['imdb_votes']
yMovieVotes = movieDummies['imdb_votes']

# %%
XShowScore = showDummies.drop(columns='imdb_score')
XMovieScore = movieDummies.drop(columns='imdb_score')
XShowVotes = showDummies.drop(columns='imdb_votes')
XMovieVotes = movieDummies.drop(columns='imdb_votes')

# %%
# Movie Score Train, Test, Scale
XtrainMS, XtestMS, ytrainMS, ytestMS = train_test_split(XMovieScore, yMovieScore, random_state=1)

scaler = StandardScaler()

XscalerMS = scaler.fit(XtrainMS)

XtrainScaledMS = XscalerMS.transform(XtrainMS)
XtestScaledMS = XscalerMS.transform(XtestMS)

# %%
# tf.keras.backend.clear_session()
nn = tf.keras.models.Sequential()


nn.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=53))

nn.add(tf.keras.layers.Dense(units=30, activation="relu"))

nn.add(tf.keras.layers.Dense(units=30, activation="relu"))

nn.add(tf.keras.layers.Dense(units=1, activation="linear"))

nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                4320
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 30)                930
#
#  dense_3 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 7,711
# Trainable params: 7,711
# Non-trainable params: 0
# _________________________________________________________________

# %%
nn.compile(loss='mean_absolute_error', optimizer="adam")

# %%
fit_model = nn.fit(XtrainScaledMS, ytrainMS, epochs=100)
# Out:
# Epoch 1/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.6003
# Epoch 2/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.6018
# Epoch 3/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5951
# Epoch 4/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5983
# Epoch 5/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5947
# Epoch 6/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5944
# Epoch 7/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5944
# Epoch 8/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5941
# Epoch 9/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5942
# Epoch 10/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5922
# Epoch 11/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5883
# Epoch 12/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5899
# Epoch 13/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5858
# Epoch 14/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5843
# Epoch 15/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5866
# Epoch 16/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5836
# Epoch 17/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5856
# Epoch 18/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5810
# Epoch 19/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5827
# Epoch 20/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5811
# Epoch 21/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5766
# Epoch 22/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5785
# Epoch 23/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5775
# Epoch 24/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5777
# Epoch 25/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5778
# Epoch 26/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5758
# Epoch 27/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5759
# Epoch 28/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5733
# Epoch 29/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5773
# Epoch 30/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5760
# Epoch 31/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5736
# Epoch 32/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5713
# Epoch 33/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5712
# Epoch 34/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5763
# Epoch 35/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5682
# Epoch 36/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5680
# Epoch 37/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5704
# Epoch 38/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5670
# Epoch 39/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5681
# Epoch 40/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5654
# Epoch 41/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5691
# Epoch 42/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5614
# Epoch 43/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5641
# Epoch 44/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5600
# Epoch 45/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5614
# Epoch 46/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5597
# Epoch 47/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5654
# Epoch 48/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5589
# Epoch 49/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5603
# Epoch 50/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5566
# Epoch 51/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5538
# Epoch 52/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5542
# Epoch 53/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5545
# Epoch 54/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5532
# Epoch 55/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5605
# Epoch 56/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5555
# Epoch 57/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5515
# Epoch 58/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5520
# Epoch 59/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5544
# Epoch 60/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5533
# Epoch 61/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5482
# Epoch 62/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5535
# Epoch 63/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5476
# Epoch 64/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5459
# Epoch 65/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5448
# Epoch 66/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5532
# Epoch 67/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5470
# Epoch 68/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5474
# Epoch 69/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5449
# Epoch 70/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5452
# Epoch 71/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5417
# Epoch 72/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5418
# Epoch 73/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5425
# Epoch 74/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5404
# Epoch 75/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5406
# Epoch 76/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5403
# Epoch 77/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5431
# Epoch 78/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5401
# Epoch 79/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5362
# Epoch 80/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5435
# Epoch 81/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5402
# Epoch 82/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5378
# Epoch 83/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5385
# Epoch 84/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5359
# Epoch 85/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5359
# Epoch 86/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5373
# Epoch 87/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5345
# Epoch 88/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5369
# Epoch 89/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5345
# Epoch 90/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5367
# Epoch 91/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5345
# Epoch 92/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5327
# Epoch 93/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5356
# Epoch 94/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5307
# Epoch 95/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5311
# Epoch 96/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5319
# Epoch 97/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5305
# Epoch 98/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5302
# Epoch 99/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5346
# Epoch 100/100
# 259/259 [==============================] - 0s 1ms/step - loss: 0.5324

# %%
model_loss = nn.evaluate(XtestScaledMS, ytestMS, verbose=2)
print(model_loss)
# Out:
# 87/87 - 0s - loss: 0.7025 - 76ms/epoch - 874us/step
# 0.7025031447410583

# %%
testPredictions = nn.predict(XtestScaledMS).flatten()
plt.scatter(ytestMS, testPredictions)
plt.xlabel('True IMDB Rating')
plt.ylabel('Predicted IMDB Rating')
plt.title('Small DNN (53 Features)')
# Out:
# 87/87 [==============================] - 0s 733us/step
# Text(0.5, 1.0, 'Small DNN (53 Features)')
